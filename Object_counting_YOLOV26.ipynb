# %%
# !uv pip install ultralytics

import ultralytics
import cv2
from ultralytics.utils.downloads import safe_download
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
safe_download("https://github.com/ultralytics/notebooks/releases/download/v0.0.0/solutions-ci-demo.mp4")
cap = cv2.VideoCapture("solutions-ci-demo.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("counting.avi",
                               cv2.VideoWriter_fourcc(*"mp4v"),
                               fps, (w, h))
# Out:
# Downloading https://github.com/ultralytics/notebooks/releases/download/v0.0.0/solutions-ci-demo.mp4 to 'solutions-ci-demo.mp4': 100% ━━━━━━━━━━━━ 264.6KB 3.0MB/s 0.1s

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    show=True,  # Display the output
    region=region_points,  # Pass region points
    model="yolo26n.pt",  # model="yolo26n-obb.pt" for object counting using YOLO26 OBB model.
    # classes=[0, 2],  # If you want to count specific classes i.e person and car with COCO pretrained model.
    # show_in=True,  # Display in counts
    # show_out=True,  # Display out counts
    # line_width=2,  # Adjust the line width for bounding boxes and text display
)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 19.5MB/s 0.3s
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()

# %%
# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = counter(im0)  # count the objects
    video_writer.write(results.plot_im)   # write the video frames

cap.release()   # Release the capture
video_writer.release()
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 399ms
# Prepared 1 package in 85ms
# Installed 1 package in 1ms
#  + lap==0.5.12
#
# requirements: AutoUpdate success ✅ 0.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# 0: 360x640 22.1ms, 18 person
# Speed: 2287.9ms track, 22.1ms solution per image at shape (1, 3, 360, 640)
#
# 1: 360x640 8.5ms, 18 person
# Speed: 157.7ms track, 8.5ms solution per image at shape (1, 3, 360, 640)
#
# 2: 360x640 3.7ms, 16 person
# Speed: 130.1ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 3: 360x640 3.9ms, 17 person
# Speed: 141.4ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 4: 360x640 3.9ms, 17 person
# Speed: 133.1ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 5: 360x640 4.6ms, 17 person
# Speed: 144.6ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 6: 360x640 4.6ms, 18 person
# Speed: 132.3ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 7: 360x640 3.9ms, 17 person
# Speed: 132.8ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 8: 360x640 4.1ms, 18 person
# Speed: 130.4ms track, 4.1ms solution per image at shape (1, 3, 360, 640)
#
# 9: 360x640 4.5ms, 22 person
# Speed: 134.4ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 10: 360x640 5.1ms, 22 person
# Speed: 130.7ms track, 5.1ms solution per image at shape (1, 3, 360, 640)
#
# 11: 360x640 4.3ms, 20 person
# Speed: 130.7ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 12: 360x640 4.4ms, 19 person
# Speed: 143.2ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 13: 360x640 5.3ms, 20 person
# Speed: 132.7ms track, 5.3ms solution per image at shape (1, 3, 360, 640)
#
# 14: 360x640 4.4ms, 19 person
# Speed: 137.7ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 15: 360x640 4.5ms, 20 person
# Speed: 129.2ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 16: 360x640 4.0ms, 18 person
# Speed: 130.5ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 17: 360x640 4.3ms, 16 person
# Speed: 131.4ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 18: 360x640 3.7ms, 17 person
# Speed: 138.3ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 19: 360x640 6.7ms, 17 person
# Speed: 147.6ms track, 6.7ms solution per image at shape (1, 3, 360, 640)
#
# 20: 360x640 3.7ms, 17 person
# Speed: 134.9ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 21: 360x640 3.9ms, 18 person
# Speed: 137.5ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 22: 360x640 4.3ms, 18 person
# Speed: 142.3ms track, 4.3ms solution per image at shape (1, 3, 360, 640)
#
# 23: 360x640 4.0ms, 18 person
# Speed: 143.8ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 24: 360x640 3.6ms, 16 person
# Speed: 144.1ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 25: 360x640 3.9ms, 16 person
# Speed: 130.7ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 26: 360x640 7.1ms, 17 person
# Speed: 139.0ms track, 7.1ms solution per image at shape (1, 3, 360, 640)
#
# 27: 360x640 3.8ms, 17 person
# Speed: 130.5ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 28: 360x640 3.8ms, 16 person
# Speed: 131.5ms track, 3.8ms solution per image at shape (1, 3, 360, 640)
#
# 29: 360x640 4.6ms, 16 person
# Speed: 130.5ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 30: 360x640 3.3ms, 14 person
# Speed: 127.5ms track, 3.3ms solution per image at shape (1, 3, 360, 640)
#
# 31: 360x640 3.4ms, 14 person
# Speed: 128.0ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 32: 360x640 3.4ms, 14 person
# Speed: 128.6ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 33: 360x640 3.4ms, 14 person
# Speed: 124.6ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 34: 360x640 3.2ms, 14 person
# Speed: 142.8ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 35: 360x640 3.2ms, 13 person
# Speed: 127.2ms track, 3.2ms solution per image at shape (1, 3, 360, 640)
#
# 36: 360x640 3.5ms, 14 person
# Speed: 127.9ms track, 3.5ms solution per image at shape (1, 3, 360, 640)
#
# 37: 360x640 3.4ms, 14 person
# Speed: 128.3ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 38: 360x640 3.4ms, 14 person
# Speed: 141.3ms track, 3.4ms solution per image at shape (1, 3, 360, 640)
#
# 39: 360x640 3.1ms, 12 person
# Speed: 142.8ms track, 3.1ms solution per image at shape (1, 3, 360, 640)
#
# 40: 360x640 2.7ms, 11 person
# Speed: 127.7ms track, 2.7ms solution per image at shape (1, 3, 360, 640)
#
# 41: 360x640 3.7ms, 16 person
# Speed: 145.5ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 42: 360x640 3.7ms, 16 person
# Speed: 128.6ms track, 3.7ms solution per image at shape (1, 3, 360, 640)
#
# 43: 360x640 3.6ms, 16 person
# Speed: 126.2ms track, 3.6ms solution per image at shape (1, 3, 360, 640)
#
# 44: 360x640 3.9ms, 17 person
# Speed: 127.4ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 45: 360x640 4.0ms, 17 person
# Speed: 135.1ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 46: 360x640 4.0ms, 18 person
# Speed: 126.8ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 47: 360x640 3.9ms, 18 person
# Speed: 129.3ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 48: 360x640 4.2ms, 19 person
# Speed: 131.7ms track, 4.2ms solution per image at shape (1, 3, 360, 640)
#
# 49: 360x640 4.5ms, 20 person
# Speed: 141.4ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 50: 360x640 3.9ms, 17 person
# Speed: 128.9ms track, 3.9ms solution per image at shape (1, 3, 360, 640)
#
# 51: 360x640 4.6ms, 18 person
# Speed: 133.6ms track, 4.6ms solution per image at shape (1, 3, 360, 640)
#
# 52: 360x640 4.0ms, 17 person
# Speed: 130.3ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 53: 360x640 4.1ms, 18 person
# Speed: 131.0ms track, 4.1ms solution per image at shape (1, 3, 360, 640)
#
# 54: 360x640 4.4ms, 19 person
# Speed: 137.5ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 55: 360x640 4.5ms, 19 person
# Speed: 135.6ms track, 4.5ms solution per image at shape (1, 3, 360, 640)
#
# 56: 360x640 4.4ms, 17 person
# Speed: 147.7ms track, 4.4ms solution per image at shape (1, 3, 360, 640)
#
# 57: 360x640 4.0ms, 18 person
# Speed: 131.0ms track, 4.0ms solution per image at shape (1, 3, 360, 640)
#
# 58: 360x640 7.3ms, 18 person
# Speed: 173.8ms track, 7.3ms solution per image at shape (1, 3, 360, 640)
#
# 59: 360x640 5.8ms, 17 person
# Speed: 197.3ms track, 5.8ms solution per image at shape (1, 3, 360, 640)
#
# 60: 360x640 5.9ms, 18 person
# Speed: 196.3ms track, 5.9ms solution per image at shape (1, 3, 360, 640)
#
# 61: 360x640 8.5ms, 19 person
# Speed: 201.4ms track, 8.5ms solution per image at shape (1, 3, 360, 640)
#
# Video frame is empty or video processing has been successfully completed.

# %%
from google.colab import files
files.download("counting.avi")
